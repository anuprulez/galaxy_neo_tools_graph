# %%
import pandas as pd

# read raw file
df = pd.read_csv("gxadmin_wf_conn.tabular", sep=' \t ')
# see columns
print(df.columns)
# update column names
df.columns = ['wf_id', 'wf_updated', 'in_id', 'in_tool', 'in_tool_v', 'out_id', 'out_tool', 'out_tool_v', 'tool_inputs', 'tool_outputs', 'published']
# remove last row
df = df[0:len(df) - 1]
# replace tab by pipe
df["tool_inputs"] = df["tool_inputs"].str.replace("\t", "|")
print(df)
df["wf_updated"] = pd.to_datetime(df["wf_updated"])
rows = len(df)
# create tsv file
f_name = "gxadmin_workflow_connections" + "_" + str(rows) + ".tsv"
df[:rows].to_csv(f_name, sep="\t", index=False)
# Out:
# /home/kumara/miniconda3/envs/graph_db/lib/python3.6/site-packages/ipykernel_launcher.py:5: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   """
# Index(['wf_id', '        wf_updated        ', 'in_id ',
#        '                                                               in_tool                                                                ',
#        '         in_tool_v          ', 'out_id',
#        '                                                               out_tool                                                               ',
#        '         out_tool_v         ',
#        '                                                        tool_inputs                                                         ',
#        '               tool_outputs                ', 'published'],
# ...

# %%
# read file
df_complete = pd.read_csv(f_name, sep='\t')
in_tool = list()
out_tool = list()
tool_input = list()
tool_output = list()

# format/clean data
size = 10000
for index, row in df_complete.iterrows():
    row['in_tool'] = row['in_tool'].strip()
    row['out_tool'] = row['out_tool'].strip()
    row['tool_inputs'] = row['tool_inputs'].strip()
    row['tool_outputs'] = row['tool_outputs'].strip()

    if len(row['in_tool']) > 0 \
        and len(row['out_tool']) > 0 \
        and len(row['tool_inputs']) > 0 \
        and len(row['tool_outputs']) > 0 \
        and index < size:

        in_tool.append(row['in_tool'])
        out_tool.append(row['out_tool'])
        tool_input.append(row['tool_inputs'])
        tool_output.append(row['tool_outputs'])
    
# save clean data as csv
corrected_data = {'in_tool': in_tool, 'out_tool': out_tool, 'tool_input': tool_input, 'tool_output': tool_output}
df_corrected_data = pd.DataFrame(corrected_data)

name = "data/corrected_gxadmin_workflow_connections_" + str(size) + ".csv"
df_corrected_data.to_csv(name, sep=",", index=False)
